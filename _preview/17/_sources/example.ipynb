# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:59570' processes=4 threads=8, memory=16.00 GiB>

# %%
import dask.array as da

x = da.random.random((10_000, 10_000), chunks=(200, 200))
x
# Out:
# dask.array<random_sample, shape=(10000, 10000), dtype=float64, chunksize=(200, 200), chunktype=numpy.ndarray>

# %%
x.std(axis=0).sum().compute()
# Out:
# 2886.72136246855
